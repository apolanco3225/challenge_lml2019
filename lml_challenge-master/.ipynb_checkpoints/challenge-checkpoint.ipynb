# %%
# import necessary pacakges
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from pickle import dump
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from pickle import dump

# %%
# labels
columns = ['Numero de Puntos', 'Radio', 'Ancho', 'Desviacion estandar con respecto al centro', 'Relacion de aspecto', 'Longitud de las fronteras', 'Regularidad de las fronteras', 'Circularidad', 'Curtosis', 'Linearidad', 'Diferencia media angular', 'Desviacion promedio de la mediana', 'Curvatura media', 'Distancia mas cercana', 'Radio del vecino mas cercano', 'Ancho del vecino mas cercano', 'Desviacion estandar con respecto al centro del vecino mas cercano', 'Relacion de aspecto del vecino mas cercano', 'Longitud de las fronteras del vecino mas cercano', 'Regularidad de las fronteras del vecino mas cercano', 'Circularidad del vecino mas cercano', 'Curtosis del vecino mas cercano', 'Linearidad del vecino mas cercano', 'Diferencia media angular', 'Desviacion promedio de la mediana del vecino mas cercano', 'Curvatura media del vecino mas cercano', 'Distancia mas cercana del vecino mas cercano del vecino mas cercano']
# load data
data = pd.read_csv('laser_data/DataTrain.csv', names=columns)
# print first 5 samples
data.head()
# Out:
#            Numero de Puntos     Radio     Ancho  \
#  0.202904         -1.018161 -0.828650 -0.869814
# -0.789145          0.081727 -0.142442 -0.223442
# -0.670627         -0.326280 -0.111944 -0.015677
# -0.278262          0.285977 -0.066197  0.249284
#  0.631027         -0.627367 -0.569416 -0.408369
#
#            Desviacion estandar con respecto al centro  Relacion de aspecto  \
#  0.202904                                   -0.329538            -0.841773
# -0.789145                                   -0.269480            -0.336376
# -0.670627                                    0.055197            -0.258640
# -0.278262                                   -0.102930             0.139696
#  0.631027                                   -0.611802            -0.586978
#
#            Longitud de las fronteras  Regularidad de las fronteras  \
#  0.202904                  -0.464735                     -0.128360
# -0.789145                  -0.437741                     -0.079900
# -0.670627                  -0.437712                     -0.092158
# -0.278262                  -0.452315                     -0.042620
#  0.631027                  -0.462924                     -0.122055
#
#            Circularidad  Curtosis  Linearidad  \
#  0.202904     -0.322477 -0.842751   -1.083076
# -0.789145     -0.320305 -0.418395   -1.014935
# -0.670627     -0.310257 -0.228230   -0.533582
# -0.278262     -0.308967  0.094664    1.469531
#  0.631027     -0.290539 -0.608660   -0.564965
#
#                                           ...                                   \
#  0.202904                                 ...
# -0.789145                                 ...
# -0.670627                                 ...
# -0.278262                                 ...
#  0.631027                                 ...
#
#            Relacion de aspecto del vecino mas cercano  \
#  0.202904                                   -1.056993
# -0.789145                                    1.623163
# -0.670627                                    0.030207
# -0.278262                                   -0.884689
#  0.631027                                    0.134014
#
#            Longitud de las fronteras del vecino mas cercano  \
#  0.202904                                         -0.195076
# -0.789145                                          0.140298
# -0.670627                                         -0.010679
# -0.278262                                         -0.195140
#  0.631027                                          0.112904
#
#            Regularidad de las fronteras del vecino mas cercano  \
#  0.202904                                          -0.163731
# -0.789145                                          -0.068669
# -0.670627                                          -0.129238
# -0.278262                                          -0.159865
#  0.631027                                          -0.129809
#
#            Circularidad del vecino mas cercano  \
#  0.202904                            -0.144460
# -0.789145                             0.254827
# -0.670627                            -0.085928
# -0.278262                            -0.143805
#  0.631027                             0.013097
#
#            Curtosis del vecino mas cercano  Linearidad del vecino mas cercano  \
#  0.202904                        -1.081824                          -0.922370
# -0.789145                         1.898572                           2.062210
# -0.670627                         0.658415                           2.236278
# -0.278262                        -0.888353                          -0.145465
#  0.631027                         0.905956                           2.087855
#
#            Diferencia media angular.1  \
#  0.202904                    0.190890
# -0.789145                    0.369629
# -0.670627                   -0.265091
# -0.278262                    0.892974
#  0.631027                    0.726240
#
#            Desviacion promedio de la mediana del vecino mas cercano  \
#  0.202904                                          -0.473240
# -0.789145                                          -0.223392
# -0.670627                                          -0.061650
# -0.278262                                           1.375719
#  0.631027                                           0.490740
#
#            Curvatura media del vecino mas cercano  \
#  0.202904                                1.793523
# -0.789145                                0.284474
# -0.670627                               -0.115872
# -0.278262                               -0.451159
#  0.631027                               -1.108378
#
#            Distancia mas cercana del vecino mas cercano del vecino mas cercano
#  0.202904                                          -0.009819
# -0.789145                                          -0.009818
# -0.670627                                          -0.009806
# -0.278262                                          -0.009814
#  0.631027                                          -0.009813
#
# [5 rows x 27 columns]

# %%
print('{} number of samples and {} features'.format(data.shape[0], data.shape[1]))
# Out:
# 14437 number of samples and 27 features

# %%
data.describe()
# Out:
#        Numero de Puntos         Radio         Ancho  \
# count      1.443700e+04  1.443700e+04  1.443700e+04
# mean      -3.562465e-13  2.071139e-12  2.701513e-13
# std        1.000000e+00  1.000000e+00  1.000000e+00
# min       -1.376594e+00 -9.658913e-01 -9.843432e-01
# 25%       -6.775754e-01 -8.286499e-01 -6.113985e-01
# 50%       -3.685639e-01 -3.101820e-01 -3.324939e-01
# 75%        1.526278e-01  1.015424e-01  2.520851e-01
# max        3.149710e+00  3.441085e+00  5.419520e+00
#
#        Desviacion estandar con respecto al centro  Relacion de aspecto  \
# count                                1.443700e+04         1.443700e+04
# mean                                -4.093617e-14         9.692063e-14
# std                                  1.000000e+00         1.000000e+00
# min                                 -4.846017e+00        -9.875970e-01
# 25%                                 -4.941081e-01        -6.333402e-01
# 50%                                 -2.434701e-01        -3.460235e-01
# 75%                                  2.207422e-01         1.761102e-01
# max                                  6.291443e+00         4.384683e+00
#
#        Longitud de las fronteras  Regularidad de las fronteras  Circularidad  \
# count               1.443700e+04                  1.443700e+04  1.443700e+04
# mean                5.265096e-13                  5.414534e-14  3.199952e-12
# std                 1.000000e+00                  1.000000e+00  1.000000e+00
# min                -4.649412e-01                 -1.399291e-01 -3.228678e-01
# 25%                -4.647847e-01                 -1.093716e-01 -3.217680e-01
# 50%                -4.453533e-01                 -8.550564e-02 -3.145273e-01
# 75%                -3.891430e-01                 -3.418166e-02 -2.372743e-01
# max                 5.636103e+00                  8.101688e+01  1.903507e+01
#
#            Curtosis    Linearidad  \
# count  1.443700e+04  1.443700e+04
# mean  -2.798005e-14 -3.127388e-14
# std    1.000000e+00  1.000000e+00
# min   -9.629847e-01 -1.267804e+00
# 25%   -6.794670e-01 -8.571894e-01
# 50%   -3.544045e-01 -2.289125e-01
# 75%    1.674367e-01  6.853843e-01
# max    4.389829e+00  5.156009e+00
#
#                                       ...                                   \
# count                                 ...
# mean                                  ...
# std                                   ...
# min                                   ...
# 25%                                   ...
# 50%                                   ...
# 75%                                   ...
# max                                   ...
#
#        Relacion de aspecto del vecino mas cercano  \
# count                                1.443700e+04
# mean                                 3.948171e-13
# std                                  1.000000e+00
# min                                 -1.202949e+00
# 25%                                 -8.052413e-01
# 50%                                 -1.612815e-01
# 75%                                  4.381369e-01
# max                                  7.918008e+00
#
#        Longitud de las fronteras del vecino mas cercano  \
# count                                      1.443700e+04
# mean                                      -1.109622e-13
# std                                        1.000000e+00
# min                                       -1.954696e-01
# 25%                                       -1.950904e-01
# 50%                                       -1.601537e-01
# 75%                                       -8.183277e-02
# max                                        2.386275e+01
#
#        Regularidad de las fronteras del vecino mas cercano  \
# count                                       1.443700e+04
# mean                                        1.373842e-13
# std                                         1.000000e+00
# min                                        -1.720569e-01
# 25%                                        -1.509005e-01
# 50%                                        -1.211213e-01
# 75%                                        -7.994744e-02
# max                                         5.539390e+01
#
#        Circularidad del vecino mas cercano  Curtosis del vecino mas cercano  \
# count                         1.443700e+04                     1.443700e+04
# mean                          2.155543e-12                    -2.742329e-14
# std                           1.000000e+00                     1.000000e+00
# min                          -1.445638e-01                    -1.204771e+00
# 25%                          -1.431203e-01                    -8.357021e-01
# 50%                          -1.300389e-01                    -1.077367e-01
# 75%                          -8.740168e-02                     4.869465e-01
# max                           6.261942e+01                     9.252352e+00
#
#        Linearidad del vecino mas cercano  Diferencia media angular.1  \
# count                       1.443700e+04                1.443700e+04
# mean                        3.281191e-13                2.077695e-14
# std                         1.000000e+00                1.000000e+00
# min                        -1.063479e+00               -2.405284e+00
# 25%                        -6.995388e-01               -5.155201e-01
# 50%                        -3.621571e-01               -4.778472e-02
# 75%                         4.055179e-01                5.478797e-01
# max                         4.663607e+00                6.993757e+00
#
#        Desviacion promedio de la mediana del vecino mas cercano  \
# count                                       1.443700e+04
# mean                                        8.309011e-14
# std                                         1.000000e+00
# min                                        -2.177032e+00
# 25%                                        -4.963494e-01
# 50%                                        -1.337566e-01
# 75%                                         3.226193e-01
# max                                         8.598491e+00
#
#        Curvatura media del vecino mas cercano  \
# count                            1.443700e+04
# mean                             5.130532e-14
# std                              1.000000e+00
# min                             -1.505624e+00
# 25%                             -8.158617e-01
# 50%                             -1.291965e-01
# 75%                              7.516892e-01
# max                              2.141769e+00
#
#        Distancia mas cercana del vecino mas cercano del vecino mas cercano
# count                                       1.443700e+04
# mean                                        2.424129e-13
# std                                         1.000000e+00
# min                                        -9.822280e-03
# 25%                                        -9.817092e-03
# 50%                                        -9.810843e-03
# 75%                                        -9.788443e-03
# max                                         1.197742e+02
#
# [8 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 14437 entries, 0.2029035206 to 0.7079977715000001
# Data columns (total 27 columns):
# Numero de Puntos                                                       14437 non-null float64
# Radio                                                                  14437 non-null float64
# Ancho                                                                  14437 non-null float64
# Desviacion estandar con respecto al centro                             14437 non-null float64
# Relacion de aspecto                                                    14437 non-null float64
# Longitud de las fronteras                                              14437 non-null float64
# Regularidad de las fronteras                                           14437 non-null float64
# Circularidad                                                           14437 non-null float64
# Curtosis                                                               14437 non-null float64
# Linearidad                                                             14437 non-null float64
# Diferencia media angular                                               14437 non-null float64
# Desviacion promedio de la mediana                                      14437 non-null float64
# Curvatura media                                                        14437 non-null float64
# Distancia mas cercana                                                  14437 non-null float64
# Radio del vecino mas cercano                                           14437 non-null float64
# Ancho del vecino mas cercano                                           14437 non-null float64
# Desviacion estandar con respecto al centro del vecino mas cercano      14437 non-null float64
# Relacion de aspecto del vecino mas cercano                             14437 non-null float64
# Longitud de las fronteras del vecino mas cercano                       14437 non-null float64
# Regularidad de las fronteras del vecino mas cercano                    14437 non-null float64
# Circularidad del vecino mas cercano                                    14437 non-null float64
# Curtosis del vecino mas cercano                                        14437 non-null float64
# Linearidad del vecino mas cercano                                      14437 non-null float64
# Diferencia media angular.1                                             14437 non-null float64
# Desviacion promedio de la mediana del vecino mas cercano               14437 non-null float64
# Curvatura media del vecino mas cercano                                 14437 non-null float64
# Distancia mas cercana del vecino mas cercano del vecino mas cercano    14437 non-null float64
# dtypes: float64(27)
# memory usage: 3.1 MB

# %%
labels = pd.read_csv('laser_data/LabelsTrain.csv', names=['human'])
print(labels.head())
# Out:
#    human
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0

# %%
print(labels['human'].value_counts())
# Out:
# 1.0    10139
# 0.0     4298
# Name: human, dtype: int64

# %%
from sklearn.model_selection import train_test_split
trainX,testX, trainY, testY = train_test_split(data.values, labels.values, test_size=0.2, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=7)

# %%
clf.fit(trainX, trainY)
# Out:
# /home/apolanco/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=7, verbose=0, warm_start=False)

# %%
predict = clf.predict(testX)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
confusion_matrix(testY, predict)
# Out:
# array([[ 777,   71],
#        [  16, 2024]])

# %%
print(classification_report(testY, predict, target_names=['human']))
# Out:
#              precision    recall  f1-score   support
#
#       human       0.98      0.92      0.95       848
#
# avg / total       0.97      0.97      0.97      2888
# /home/apolanco/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 2, does not match size of target_names, 1
#   .format(len(labels), len(target_names))

# %%
# nombre del archivo
filename = 'first_model.pkl'
dump(clf, open(filename, 'wb' ))
